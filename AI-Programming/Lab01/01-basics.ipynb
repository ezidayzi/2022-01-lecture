# %%
import tensorflow as tf

hello = tf.constant("Hello TensorFlow!")

sess = tf.Session()

print(sess.run(hello))
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ERROR! Session/line number was not unique in database. History logging moved to new session 61
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-7b871a40c087>", line 3, in <module>
#     hello = tf.constant("Hello TensorFlow!")
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/util/module_wrapper.py", line 193, in __getattr__
#     set([
# AttributeError: module 'tensorflow' has no attribute 'constant'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 941, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/__init__.py", line 42, in <module>
#     from . _api.v2 import audio
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/_api/v2/audio/__init__.py", line 10, in <module>
#     from tensorflow.python.ops.gen_audio_ops import decode_wav
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_audio_ops.py", line 11, in <module>
#     from tensorflow.python.eager import context as _context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py", line 29, in <module>
#     from tensorflow.core.protobuf import config_pb2
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/core/protobuf/config_pb2.py", line 7, in <module>
#     from google.protobuf import descriptor as _descriptor
# ModuleNotFoundError: No module named 'google.protobuf'
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-7b871a40c087>", line 3, in <module>
#     hello = tf.constant("Hello TensorFlow!")
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/util/module_wrapper.py", line 193, in __getattr__
#     set([
# AttributeError: module 'tensorflow' has no attribute 'constant'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 941, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/__init__.py", line 42, in <module>
#     from . _api.v2 import audio
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/_api/v2/audio/__init__.py", line 10, in <module>
#     from tensorflow.python.ops.gen_audio_ops import decode_wav
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_audio_ops.py", line 11, in <module>
#     from tensorflow.python.eager import context as _context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py", line 29, in <module>
#     from tensorflow.core.protobuf import config_pb2
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/core/protobuf/config_pb2.py", line 7, in <module>
#     from google.protobuf import descriptor as _descriptor
# ModuleNotFoundError: No module named 'google.protobuf'
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-7b871a40c087>", line 3, in <module>
#     hello = tf.constant("Hello TensorFlow!")
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/util/module_wrapper.py", line 193, in __getattr__
#     set([
# AttributeError: module 'tensorflow' has no attribute 'constant'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3282, in run_ast_nodes
#     self.showtraceback()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1211, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 941, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/__init__.py", line 42, in <module>
#     from . _api.v2 import audio
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/_api/v2/audio/__init__.py", line 10, in <module>
#     from tensorflow.python.ops.gen_audio_ops import decode_wav
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_audio_ops.py", line 11, in <module>
#     from tensorflow.python.eager import context as _context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py", line 29, in <module>
#     from tensorflow.core.protobuf import config_pb2
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/core/protobuf/config_pb2.py", line 7, in <module>
#     from google.protobuf import descriptor as _descriptor
# ModuleNotFoundError: No module named 'google.protobuf'

# %%
# 그래프 빌드
node1 = tf.constant(3.0, tf.float32)
node2 = tf.constant(4.0,)
node3 = tf.add(node1, node2)

# 그래프의 하나의 요소인 것만 리턴 (= tensor)
print("node1: ", node1, "node2: ", node2)
print("node3: ", node3)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ERROR! Session/line number was not unique in database. History logging moved to new session 62
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-148a3cc0aecf>", line 2, in <module>
#     node1 = tf.constant(3.0, tf.float32)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/util/module_wrapper.py", line 193, in __getattr__
#     set([
# AttributeError: module 'tensorflow' has no attribute 'constant'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 941, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/__init__.py", line 42, in <module>
#     from . _api.v2 import audio
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/_api/v2/audio/__init__.py", line 10, in <module>
#     from tensorflow.python.ops.gen_audio_ops import decode_wav
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_audio_ops.py", line 11, in <module>
#     from tensorflow.python.eager import context as _context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py", line 29, in <module>
#     from tensorflow.core.protobuf import config_pb2
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/core/protobuf/config_pb2.py", line 7, in <module>
#     from google.protobuf import descriptor as _descriptor
# ModuleNotFoundError: No module named 'google.protobuf'
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-148a3cc0aecf>", line 2, in <module>
#     node1 = tf.constant(3.0, tf.float32)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/util/module_wrapper.py", line 193, in __getattr__
#     set([
# AttributeError: module 'tensorflow' has no attribute 'constant'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 941, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/__init__.py", line 42, in <module>
#     from . _api.v2 import audio
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/_api/v2/audio/__init__.py", line 10, in <module>
#     from tensorflow.python.ops.gen_audio_ops import decode_wav
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_audio_ops.py", line 11, in <module>
#     from tensorflow.python.eager import context as _context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py", line 29, in <module>
#     from tensorflow.core.protobuf import config_pb2
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/core/protobuf/config_pb2.py", line 7, in <module>
#     from google.protobuf import descriptor as _descriptor
# ModuleNotFoundError: No module named 'google.protobuf'
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-148a3cc0aecf>", line 2, in <module>
#     node1 = tf.constant(3.0, tf.float32)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/util/module_wrapper.py", line 193, in __getattr__
#     set([
# AttributeError: module 'tensorflow' has no attribute 'constant'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3282, in run_ast_nodes
#     self.showtraceback()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1211, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 941, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/__init__.py", line 42, in <module>
#     from . _api.v2 import audio
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/_api/v2/audio/__init__.py", line 10, in <module>
#     from tensorflow.python.ops.gen_audio_ops import decode_wav
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_audio_ops.py", line 11, in <module>
#     from tensorflow.python.eager import context as _context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py", line 29, in <module>
#     from tensorflow.core.protobuf import config_pb2
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/core/protobuf/config_pb2.py", line 7, in <module>
#     from google.protobuf import descriptor as _descriptor
# ModuleNotFoundError: No module named 'google.protobuf'

# %%
# 그래프 실행 -> 리턴값 있으면 리턴
sess = tf.Session()
print("sess.run([node1, node2])", sess.run([node1, node2]))
print("sess.run(node3)", sess.run(node3))
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ERROR! Session/line number was not unique in database. History logging moved to new session 63
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-092a6edb2289>", line 2, in <module>
#     sess = tf.Session()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/util/module_wrapper.py", line 193, in __getattr__
#     set([
# AttributeError: module 'tensorflow' has no attribute 'Session'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 941, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/__init__.py", line 42, in <module>
#     from . _api.v2 import audio
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/_api/v2/audio/__init__.py", line 10, in <module>
#     from tensorflow.python.ops.gen_audio_ops import decode_wav
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_audio_ops.py", line 11, in <module>
#     from tensorflow.python.eager import context as _context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py", line 29, in <module>
#     from tensorflow.core.protobuf import config_pb2
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/core/protobuf/config_pb2.py", line 7, in <module>
#     from google.protobuf import descriptor as _descriptor
# ModuleNotFoundError: No module named 'google.protobuf'
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-092a6edb2289>", line 2, in <module>
#     sess = tf.Session()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/util/module_wrapper.py", line 193, in __getattr__
#     set([
# AttributeError: module 'tensorflow' has no attribute 'Session'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 941, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/__init__.py", line 42, in <module>
#     from . _api.v2 import audio
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/_api/v2/audio/__init__.py", line 10, in <module>
#     from tensorflow.python.ops.gen_audio_ops import decode_wav
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_audio_ops.py", line 11, in <module>
#     from tensorflow.python.eager import context as _context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py", line 29, in <module>
#     from tensorflow.core.protobuf import config_pb2
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/core/protobuf/config_pb2.py", line 7, in <module>
#     from google.protobuf import descriptor as _descriptor
# ModuleNotFoundError: No module named 'google.protobuf'
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-092a6edb2289>", line 2, in <module>
#     sess = tf.Session()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/util/module_wrapper.py", line 193, in __getattr__
#     set([
# AttributeError: module 'tensorflow' has no attribute 'Session'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3282, in run_ast_nodes
#     self.showtraceback()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1211, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 941, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/__init__.py", line 42, in <module>
#     from . _api.v2 import audio
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/_api/v2/audio/__init__.py", line 10, in <module>
#     from tensorflow.python.ops.gen_audio_ops import decode_wav
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_audio_ops.py", line 11, in <module>
#     from tensorflow.python.eager import context as _context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py", line 29, in <module>
#     from tensorflow.core.protobuf import config_pb2
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/core/protobuf/config_pb2.py", line 7, in <module>
#     from google.protobuf import descriptor as _descriptor
# ModuleNotFoundError: No module named 'google.protobuf'

# %%
# Placeholder
a = tf.placeholder(tf.float32)
b = tf.placeholder(tf.float32)
adder_node = a+b

print(sess.run(adder_node, feed_dict={a: 3, b: 4.5}))
print(sess.run(adder_node, feed_dict={a: [1, 3], b: [2, 4]}))
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# ERROR! Session/line number was not unique in database. History logging moved to new session 64
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-2b2bc2fa3be4>", line 2, in <module>
#     a = tf.placeholder(tf.float32)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/util/module_wrapper.py", line 193, in __getattr__
#     set([
# AttributeError: module 'tensorflow' has no attribute 'placeholder'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 941, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/__init__.py", line 42, in <module>
#     from . _api.v2 import audio
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/_api/v2/audio/__init__.py", line 10, in <module>
#     from tensorflow.python.ops.gen_audio_ops import decode_wav
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_audio_ops.py", line 11, in <module>
#     from tensorflow.python.eager import context as _context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py", line 29, in <module>
#     from tensorflow.core.protobuf import config_pb2
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/core/protobuf/config_pb2.py", line 7, in <module>
#     from google.protobuf import descriptor as _descriptor
# ModuleNotFoundError: No module named 'google.protobuf'
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-2b2bc2fa3be4>", line 2, in <module>
#     a = tf.placeholder(tf.float32)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/util/module_wrapper.py", line 193, in __getattr__
#     set([
# AttributeError: module 'tensorflow' has no attribute 'placeholder'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 941, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/__init__.py", line 42, in <module>
#     from . _api.v2 import audio
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/_api/v2/audio/__init__.py", line 10, in <module>
#     from tensorflow.python.ops.gen_audio_ops import decode_wav
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_audio_ops.py", line 11, in <module>
#     from tensorflow.python.eager import context as _context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py", line 29, in <module>
#     from tensorflow.core.protobuf import config_pb2
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/core/protobuf/config_pb2.py", line 7, in <module>
#     from google.protobuf import descriptor as _descriptor
# ModuleNotFoundError: No module named 'google.protobuf'
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-2b2bc2fa3be4>", line 2, in <module>
#     a = tf.placeholder(tf.float32)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/util/module_wrapper.py", line 193, in __getattr__
#     set([
# AttributeError: module 'tensorflow' has no attribute 'placeholder'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3263, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3360, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1193, in structured_traceback
#     tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2895, in _run_cell
#     return runner(coro)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3072, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3282, in run_ast_nodes
#     self.showtraceback()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2047, in showtraceback
#     value, tb, tb_offset=tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1436, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1336, in structured_traceback
#     self, etype, value, tb, tb_offset, number_of_lines_of_context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1211, in structured_traceback
#     chained_exceptions_tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1150, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 451, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 941, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 994, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 971, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 955, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/__init__.py", line 42, in <module>
#     from . _api.v2 import audio
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/_api/v2/audio/__init__.py", line 10, in <module>
#     from tensorflow.python.ops.gen_audio_ops import decode_wav
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/ops/gen_audio_ops.py", line 11, in <module>
#     from tensorflow.python.eager import context as _context
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/python/eager/context.py", line 29, in <module>
#     from tensorflow.core.protobuf import config_pb2
#   File "/Users/kimyoonseo/opt/anaconda3/envs/myvenv/lib/python3.6/site-packages/tensorflow_core/core/protobuf/config_pb2.py", line 7, in <module>
#     from google.protobuf import descriptor as _descriptor
# ModuleNotFoundError: No module named 'google.protobuf'
